# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
# url = "https://livingliquidz.com/"

# r = requests.get(url)
# soup = BeautifulSoup(r.content, 'html.parser')

# # Save the HTML content to a file
# with open("page.html", "w", encoding="utf-8") as file:
#     file.write(soup.prettify())

# %%
# Open the HTML file and read its content
with open("page.html", "r", encoding="utf-8") as file:
    html_content = file.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Now you can work with the parsed soup object
# For example, printing the prettified HTML
# print(soup.prettify())

# %%
anchors = soup.find_all('a')
print("len :", len(anchors))
# Out:
# len : 281

# %%
anchors[0].find(class_ = "whatsapp-badge d-none d-lg-block")

# %%
url = "https://livingliquidz.com/"

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

# %%
for i in soup.find_all("a"):
    print(i.get("href"))
# Out:
# whatsapp://send?phone=+917700000770
# tel:7700000770
# javascript:void(0);
# https://wa.me/917700000770
# /
# /product/search
# /Cart
# /
# #
# /App/Products?rootCategorySlug=spirits&categorySlug=blended-indian-whiskey&categoryId=941
# /App/Products?rootCategorySlug=spirits&categorySlug=premium-indian-whiskey&categoryId=942
# /App/Products?rootCategorySlug=spirits&categorySlug=indian-indian-whiskey&categoryId=1082
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# /
# #
# /products/indian-whiskey/blended-indian-whiskey/941
# /products/indian-whiskey/premium-indian-whiskey/942
# /products/indian-whiskey/indian-indian-whiskey/1082
# /products/gin/plain-indian-gin/1621
# /products/gin/FLAVOURE/1717
# /products/gin/indian-gin/347
# /products/gin/JAPANESE%20GIN/1714
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup

# Open the HTML file and read its content
with open("page.html", "r", encoding="utf-8") as file:
    html_content = file.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Now you can work with the parsed soup object
# For example, printing the prettified HTML
# print(soup.prettify())

# %%
soup = BeautifulSoup(requests.get("""https://livingliquidz.com""").content, 'html.parser')

# %%
<div class="row g-4 justify-content-end">
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Region/pa_region/304/2" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Region</a>
                    </div>
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Country/pa_country/304/3" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Country</a>
                    </div>
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Grapes/pa_grapes/304/7" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Grapes</a>
                    </div>
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Styles/pa_style/304/8" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Styles</a>
                    </div>
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Types/pa_type/304/9" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Types</a>
                    </div>
                    <div class="col-6">
                        <a href="/product-category/Wine%20By%20Brand/pa_brand/304/6" class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill">Wines by Brand</a>
                    </div>
                </div>

# %%
soup.find("div", class_="row g-4 justify-content-end").find_all("div", class_="col-3")
# Out:
# []

# %%
soup.find("div", class_="row g-4 justify-content-end").find_all("div", class_="col-3")
# Out:
# []

# %%
BeautifulSoup(soup.find("div", class_="row g-4 justify-content-end").encode_contents(), 'html.parser')
# Out:
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Region/pa_region/304/2">Wines by Region</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Country/pa_country/304/3">Wines by Country</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Grapes/pa_grapes/304/7">Wines by Grapes</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Styles/pa_style/304/8">Wines by Styles</a>
# </div>
# <div class="col-6">
# ...

# %%
from bs4 import BeautifulSoup

html_content = soup.find("div", class_="row g-4 justify-content-end").encode_contents()
parsed_html = BeautifulSoup(html_content, 'html.parser')
parsed_html
# Out:
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Region/pa_region/304/2">Wines by Region</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Country/pa_country/304/3">Wines by Country</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Grapes/pa_grapes/304/7">Wines by Grapes</a>
# </div>
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Styles/pa_style/304/8">Wines by Styles</a>
# </div>
# <div class="col-6">
# ...

# %%
from bs4 import BeautifulSoup

html_content = soup.find("div", class_="row g-4 justify-content-end").encode_contents()
parsed_html = BeautifulSoup(html_content, 'html.parser')

output_list = [item.get_text(strip=True) for item in parsed_html.find_all('div')]
print(output_list)
# Out:
# ['Wines by Region', 'Wines by Country', 'Wines by Grapes', 'Wines by Styles', 'Wines by Types', 'Wines by Brand']

# %%
for i in BeautifulSoup(soup.find("div", class_="row g-4 justify-content-end").encode_contents(), 'html.parser'):
    text = i.text.strip()
    if text:
        print(text)
# Out:
# Wines by Region
# Wines by Country
# Wines by Grapes
# Wines by Styles
# Wines by Types
# Wines by Brand

# %%
for i in BeautifulSoup(soup.find("div", class_="row g-4 justify-content-end").encode_contents(), 'html.parser'):
    print(i)
# Out:
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Region/pa_region/304/2">Wines by Region</a>
# </div>
#
#
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Country/pa_country/304/3">Wines by Country</a>
# </div>
#
#
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Grapes/pa_grapes/304/7">Wines by Grapes</a>
# </div>
#
#
# <div class="col-6">
# <a class="btn default-link btn-sm w-100 btn-light text-dark text-uppercase fw-500 fs-14 fs-lg-18 zoom-hover rounded-pill" href="/product-category/Wine%20By%20Styles/pa_style/304/8">Wines by Styles</a>
# </div>
#
#
# <div class="col-6">
# ...

# %%
from bs4 import BeautifulSoup

div_elements = soup.select("div.row.g-4.justify-content-end div.col-6")

for div in div_elements:
    a_element = div.find("a")
    print(a_element.text.strip())
# Out:
# Wines by Region
# Wines by Country
# Wines by Grapes
# Wines by Styles
# Wines by Types
# Wines by Brand

# %%
soup = BeautifulSoup(requests.get("""https://livingliquidz.com/product-category/Wine%20By%20Region/pa_region/304/2""").content, 'html.parser')

for i in soup.find_all("a", class_='mx-3 p-3 mb-3 rounded-m bg-white shadow-m d-block text-wine font-18 font-600'):
    print(i.text.strip())
# Out:
# ABRUZZO - ITALY (5)
# ADELAIDE HILLS - AUSTRALIA (2)
# AGRELO - AREGENTINA (1)
# ALSACE - FRANCE (1)
# AZEITAO - PORTUGAL (1)
# BANGALORE - INDIA (5)
# BARBERA D ASTI - ITALY (1)
# BEAUJOLAIS VILLAGES - FRANCE (1)
# BOLGHERI - ITALY (1)
# BORDEAUX - FRANCE (18)
# BOURGOGNE - FRANCE (3)
# BURGENLAND - AUSTRIA (1)
# BURGUNDY - FRANCE (8)
# CALIFORNIA - USA (18)
# CANOSA DI PUGLIA - ITALY (1)
# CARINENA - ITALY (1)
# CARSKBURG - USA (1)
# CASTILLA Y LEON - SPAIN (2)
# CATALUNYA - SPAIN (10)
# CENTRAL COAST - USA (3)
# CENTRAL VALLEY - CHILE (16)
# CHABLIS - FRANCE (2)
# CHAMPAGNE - FRANCE (6)
# CHATEAUNEUF DU PAPE - FRANCE (1)
# CHIANTI - ITALY (5)
# CHILE / CENTRAL VALLEY / MAIPO VALLEY (3)
# COASTAL REGION - SOUTH AFRICA (2)
# COLUMBIA VALLEY (1)
# COTES DE GASCOGNE - FRANCE (1)
# COTES DE PROVENCE - FRANCE (3)
# COTES DU RHONE - FRANCE (3)
# CREMANT DE BOURGOGNE - FRANCE (1)
# D ABRUZZO (3)
# DELLE VENEZIE - ITALY (1)
# EMILIA ROMAGNA - ITALY (5)
# FRANSCHHOEK - SOUTH AFRICA (3)
# ...

# %%
prefix = """https://livingliquidz.com"""
for i in soup.find_all("a", class_='mx-3 p-3 mb-3 rounded-m bg-white shadow-m d-block text-wine font-18 font-600'):
    print(prefix + i.get("href"))
# Out:
# https://livingliquidz.com/products/Wine%20By%20Region/ABRUZZO---ITALY/304?attributeCollectionID=443
# https://livingliquidz.com/products/Wine%20By%20Region/ADELAIDE-HILLS---AUSTRALIA/304?attributeCollectionID=324
# https://livingliquidz.com/products/Wine%20By%20Region/AGRELO---AREGENTINA/304?attributeCollectionID=389
# https://livingliquidz.com/products/Wine%20By%20Region/ALSACE---FRANCE/304?attributeCollectionID=248
# https://livingliquidz.com/products/Wine%20By%20Region/AZEITAO---PORTUGAL/304?attributeCollectionID=326
# https://livingliquidz.com/products/Wine%20By%20Region/BANGALORE---INDIA/304?attributeCollectionID=516
# https://livingliquidz.com/products/Wine%20By%20Region/BARBERA-D-ASTI---ITALY/304?attributeCollectionID=621
# https://livingliquidz.com/products/Wine%20By%20Region/BEAUJOLAIS-VILLAGES---FRANCE/304?attributeCollectionID=912
# https://livingliquidz.com/products/Wine%20By%20Region/BOLGHERI---ITALY/304?attributeCollectionID=274
# ...
